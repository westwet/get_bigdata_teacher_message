# %%
import jieba
import collections
import wordcloud

# %%
list0 = jieba.cut('复旦大学（Fudan University）简称“复旦”，位于中国上海，由中华人民共和国教育部直属，中央直管副部级建制，国家“双一流”（A类）、“985工程”、“211工程”建设高校，九校联盟、环太平洋大学联盟、中国大学校长联谊会、东亚研究型大学协会、新工科教育国际联盟、长三角研究型大学联盟的重要成员，入选“珠峰计划”、“111计划”、“2011计划”、卓越医生教育培养计划、卓越法律人才教育培养计划、国家建设高水平大学公派研究生项目、中国政府奖学金来华留学生接收院校、全国首批深化创新创业教育改革示范高校，是一所世界知名、国内顶尖的全国重点大学。\
复旦大学校名取自《尚书大传》之“日月光华，旦复旦兮”，始创于1905年，原名复旦公学，1917年定名复旦大学，是中国人自主创办的第一所高等院校。上海医科大学前身是1927年创办的国立第四中山大学医学院。2000年，复旦大学与上海医科大学合并，组建新的复旦大学。 [1-2] \
截至2017年12月31日，学校有四个校区，占地面积244.99万平方米，校舍建筑面积198.22万平方米。 [2] \
2019年6月19日，2020QS世界大学排名发布，复旦大学位列第40位。')

# %%
word_counts = collections.Counter(list(list0))

# %%
word_counts
# Out:
# Counter({'复旦大学': 6,
#          '（': 2,
#          'Fudan': 1,
#          ' ': 5,
#          'University': 1,
#          '）': 2,
#          '简称': 1,
#          '“': 8,
#          '复旦': 3,
#          '”': 8,
#          '，': 19,
#          '位于': 1,
#          '中国': 2,
#          '上海': 1,
#          '由': 1,
#          '中华人民共和国教育部': 1,
#          '直属': 1,
#          '中央': 1,
#          '直管': 1,
#          '副部级': 1,
#          '建制': 1,
#          '国家': 2,
#          '双': 1,
#          '一流': 1,
#          'A': 1,
#          '类': 1,
#          '、': 15,
#          '985': 1,
#          '工程': 2,
#          '211': 1,
#          '建设': 2,
#          '高校': 2,
#          '九校': 1,
#          '联盟': 3,
#          '环': 1,
#          '太平洋': 1,
#          '大学': 5,
#          '中国大学': 1,
#          '校长': 1,
#          '联谊会': 1,
#          '东亚': 1,
#          '研究型': 2,
#          '协会': 1,
#          '新': 2,
#          '工科': 1,
#          '教育': 2,
#          '国际联盟': 1,
#          '长三角': 1,
#          '的': 5,
# ...

# %%
wd = wordcloud.WordCloud(font_path="C:\\Windows\\Fonts\\MSYH",background_color="white").generate_from_frequencies(word_counts)

# %%
wd.to_file("C:\\Users\\NYDSJ\\Desktop\\try.png")
